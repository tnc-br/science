# %%
import arcpy

# %%
def config_sicar():  # 01_config_iniciais_car

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    imoveis_sicar = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\imoveis_sicar"

    # Process: Add Field (2) (Add Field) (management)
    imoveis_sicar_2_ = arcpy.management.AddField(in_table=imoveis_sicar, field_name="perfil_imovel", field_type="TEXT", field_alias="perfil_imovel", field_is_nullable="NULLABLE")[0]

    # Process: Calculate Field (2) (Calculate Field) (management)
    imoveis_sicar_4_ = arcpy.management.CalculateField(in_table=imoveis_sicar_2_, field="perfil_imovel", expression="reclass(!mod_fiscais!)", code_block="""def reclass(mod_fiscais):
    if (mod_fiscais <= 4):
        return \"SICAR Pequeno\"
    elif (mod_fiscais > 4 and mod_fiscais <= 15):
        return \"SICAR Medio\"
    elif (mod_fiscais > 15):
        return \"SICAR Grande\"
""")[0]

    # Process: Copy Features (Copy Features) (management)
    stp01_sicar_mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp01_sicar_mf"
    arcpy.management.CopyFeatures(in_features=imoveis_sicar_4_, out_feature_class=stp01_sicar_mf)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        config_sicar()

# %%
def tratamento_uc():  # 02_tratamento_uc

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    uc_mma = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\uc_mma"

    # Process: Select Layer By Attribute (3) (Select Layer By Attribute) (management)
    uc_mma_Layer, Count_3_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=uc_mma, where_clause="categoria = 'Área de Proteção Ambiental'")

    # Process: Export Features (Export Features) (conversion)
    stp3_apas_mma = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma"
    arcpy.conversion.ExportFeatures(in_features=uc_mma_Layer, out_features=stp3_apas_mma, field_mapping="fid_1 \"fid_1\" true true false 8 Double 0 0,First,#,uc_mma_Layer,fid_1,-1,-1;id_uc \"id_uc\" true true false 254 Text 0 0,First,#,uc_mma_Layer,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,uc_mma_Layer,nome_uc,0,254;wdpa_pid \"wdpa_pid\" true true false 254 Text 0 0,First,#,uc_mma_Layer,wdpa_pid,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,uc_mma_Layer,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,uc_mma_Layer,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,uc_mma_Layer,esfera,0,254;ano_criaca \"ano_criaca\" true true false 254 Text 0 0,First,#,uc_mma_Layer,ano_criaca,0,254;qualidade \"qualidade\" true true false 254 Text 0 0,First,#,uc_mma_Layer,qualidade,0,254;ato_criaca \"ato_criaca\" true true false 254 Text 0 0,First,#,uc_mma_Layer,ato_criaca,0,254;codigo_uc \"codigo_uc\" true true false 254 Text 0 0,First,#,uc_mma_Layer,codigo_uc,0,254;nome_og \"nome_og\" true true false 254 Text 0 0,First,#,uc_mma_Layer,nome_og,0,254;hectares \"hectares\" true true false 8 Double 0 0,First,#,uc_mma_Layer,hectares,-1,-1;nome_abrev \"nome_abrev\" true true false 254 Text 0 0,First,#,uc_mma_Layer,nome_abrev,0,254;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,uc_mma_Layer,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,uc_mma_Layer,Shape_Area,-1,-1")

    # Process: Copy Features (2) (Copy Features) (management)
    stp3_uc_sem_apa_mma = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma"
    arcpy.management.CopyFeatures(in_features=uc_mma, out_feature_class=stp3_uc_sem_apa_mma)

    # Process: Select Layer By Attribute (4) (Select Layer By Attribute) (management)
    uc_sem_apa_mma_Layer1, Count_4_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp3_uc_sem_apa_mma, where_clause="categoria = 'Área de Proteção Ambiental'")

    # Process: Delete Rows (3) (Delete Rows) (management)
    Updated_Input_With_Rows_Removed_3_ = arcpy.management.DeleteRows(in_rows=uc_sem_apa_mma_Layer1)[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        tratamento_uc()

# %%
def tratamento_car():  # 03_tratamento_car

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp01_sicar_mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp01_sicar_mf"
    stp02_sicar_mf_at_pe_iru_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp02_sicar_mf_at_pe_iru"
    stp02_sicar_mf_at_pe_iru_2_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp02_sicar_mf_at_pe_iru"

    # Process: Copy Features (Copy Features) (management)
    stp02_sicar_mf_at_pe_iru = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp02_sicar_mf_at_pe_iru"
    arcpy.management.CopyFeatures(in_features=stp01_sicar_mf, out_feature_class=stp02_sicar_mf_at_pe_iru)

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp02_sicar_mf_at_pe_iru_Lay, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp02_sicar_mf_at_pe_iru, where_clause="ind_status IN ('CA', 'SU')")

    # Process: Delete Rows (Delete Rows) (management)
    Updated_Input_With_Rows_Removed = arcpy.management.DeleteRows(in_rows=stp02_sicar_mf_at_pe_iru_Lay)[0]

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    stp02_sicar_mf_at_pe_iru_Lay_2_, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=Updated_Input_With_Rows_Removed, where_clause="ind_tipo_i IN ('AST', 'PCT')")

    # Process: Delete Rows (2) (Delete Rows) (management)
    Updated_Input_With_Rows_Removed_2_ = arcpy.management.DeleteRows(in_rows=stp02_sicar_mf_at_pe_iru_Lay_2_)[0]

    # Process: Repair Geometry (Repair Geometry) (management)
    Repaired_Input_Features = arcpy.management.RepairGeometry(in_features=stp02_sicar_mf_at_pe_iru_3_)[0]

    # Process: Select Layer By Attribute (5) (Select Layer By Attribute) (management)
    stp02_sicar_mf_at_pe_iru_Lay1, Count_6_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp02_sicar_mf_at_pe_iru_2_, where_clause="perfil_imovel = 'SICAR Grande'")

    # Process: Select Layer By Attribute (6) (Select Layer By Attribute) (management)
    stp02_sicar_mf_at_pe_iru_Lay2, Count_7_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp02_sicar_mf_at_pe_iru_2_, where_clause="perfil_imovel = 'SICAR Medio'")

    # Process: Select Layer By Attribute (7) (Select Layer By Attribute) (management)
    stp02_sicar_mf_at_pe_iru_Lay3, Count_8_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp02_sicar_mf_at_pe_iru_2_, where_clause="perfil_imovel = 'SICAR Pequeno'")

    # Process: Copy Features (4) (Copy Features) (management)
    stp4_sicar_grande = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_grande"
    arcpy.management.CopyFeatures(in_features=stp02_sicar_mf_at_pe_iru_Lay1, out_feature_class=stp4_sicar_grande)

    # Process: Copy Features (5) (Copy Features) (management)
    stp4_sicar_medio = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_medio"
    arcpy.management.CopyFeatures(in_features=stp02_sicar_mf_at_pe_iru_Lay2, out_feature_class=stp4_sicar_medio)

    # Process: Copy Features (6) (Copy Features) (management)
    stp4_sicar_pequeno = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_pequeno"
    arcpy.management.CopyFeatures(in_features=stp02_sicar_mf_at_pe_iru_Lay3, out_feature_class=stp4_sicar_pequeno)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        tratamento_car()

# %%
def trat_sobreposicao_pequenos():  # 04_trat_sobreposicao_pequenos

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp4_sicar_pequeno = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_pequeno"
    stp4_sicar_pequeno_4_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_pequeno"
    stp4_sicar_pequeno_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_pequeno"

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp4_sicar_pequeno_Layer, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp4_sicar_pequeno, where_clause="mod_fiscais <= 1")

    # Process: Export Features (Export Features) (conversion)
    stp6_sicar_peq_1mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp6_sicar_peq_1mf"
    arcpy.conversion.ExportFeatures(in_features=stp4_sicar_pequeno_Layer, out_features=stp6_sicar_peq_1mf, field_mapping="area_ha \"area_imove\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,stp4_sicar_pequeno_Layer,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,stp4_sicar_pequeno_Layer,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,stp4_sicar_pequeno_Layer,perfil_imovel,0,255;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (2) (Remove Overlap (multiple)) (analysis)
    stp61_sicar_peq_1mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp61_sicar_peq_1mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp6_sicar_peq_1mf], out_feature_class=stp61_sicar_peq_1mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (3) (Select Layer By Attribute) (management)
    stp4_sicar_pequeno_Layer2, Count_3_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp4_sicar_pequeno_4_, where_clause="mod_fiscais > 2")

    # Process: Export Features (3) (Export Features) (conversion)
    stp6_sicar_peq_2a4mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp6_sicar_peq_2a4mf"
    arcpy.conversion.ExportFeatures(in_features=stp4_sicar_pequeno_Layer2, out_features=stp6_sicar_peq_2a4mf, field_mapping="area_ha \"area_imove\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer2,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,stp4_sicar_pequeno_Layer2,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,stp4_sicar_pequeno_Layer2,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer2,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,stp4_sicar_pequeno_Layer2,perfil_imovel,0,255;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer2,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer2,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (3) (Remove Overlap (multiple)) (analysis)
    stp61_sicar_peq_2a4mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp61_sicar_peq_2a4mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp6_sicar_peq_2a4mf], out_feature_class=stp61_sicar_peq_2a4mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    stp4_sicar_pequeno_Layer1, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp4_sicar_pequeno_3_, where_clause="mod_fiscais > 1 And mod_fiscais <= 2")

    # Process: Export Features (2) (Export Features) (conversion)
    stp6_sicar_peq_1a2mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp6_sicar_peq_1a2mf"
    arcpy.conversion.ExportFeatures(in_features=stp4_sicar_pequeno_Layer1, out_features=stp6_sicar_peq_1a2mf, field_mapping="area_ha \"area_imove\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer1,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,stp4_sicar_pequeno_Layer1,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,stp4_sicar_pequeno_Layer1,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer1,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,stp4_sicar_pequeno_Layer1,perfil_imovel,0,255;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer1,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp4_sicar_pequeno_Layer1,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (4) (Remove Overlap (multiple)) (analysis)
    stp61_sicar_peq_1a2mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp61_sicar_peq_1a2mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp6_sicar_peq_1a2mf], out_feature_class=stp61_sicar_peq_1a2mf_woverlap, method="THIESSEN")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sobreposicao_pequenos()

# %%
def trat_sobreposicao_pequenos2():  # 4_1_cont_trat_sobrep_pequenos

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp61_sicar_peq_2a4mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_2a4mf_woverlap"
    stp61_sicar_peq_1a2mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1a2mf_woverlap"
    stp61_sicar_peq_1mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap"

    # Process: Erase (Erase) (analysis)
    stp62_sicar_peq_1mf_1a2mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase"
    arcpy.analysis.Erase(in_features=stp61_sicar_peq_1a2mf_woverlap_3_, erase_features=stp61_sicar_peq_1mf_woverlap_3_, out_feature_class=stp62_sicar_peq_1mf_1a2mf_erase)

    # Process: Merge (Merge) (management)
    stp62_sicar_peq_1mf_1a_Merge = "C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge"
    arcpy.management.Merge(inputs=[stp62_sicar_peq_1mf_1a2mf_erase, stp61_sicar_peq_1mf_woverlap_3_], output=stp62_sicar_peq_1mf_1a_Merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,sicar_pa_ind_status,0,2,C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,sicar_pa_ind_tipo_i,0,3,C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,perfil_imov,0,255,C:\\unidades_territoriais\\database_uts.gdb\\stp61_sicar_peq_1mf_woverlap,perfil_imovel,0,255;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp62_sicar_peq_1mf_1a2mf_erase,Shape_Area,-1,-1")

    # Process: Erase (2) (Erase) (analysis)
    stp63_sicar_peq_1a2mf_2a4mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase"
    arcpy.analysis.Erase(in_features=stp61_sicar_peq_2a4mf_woverlap_3_, erase_features=stp62_sicar_peq_1mf_1a_Merge, out_feature_class=stp63_sicar_peq_1a2mf_2a4mf_erase)

    # Process: Merge (2) (Merge) (management)
    stp63_sicar_peq_1a2mf_2a4mf_merge = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_merge"
    arcpy.management.Merge(inputs=[stp63_sicar_peq_1a2mf_2a4mf_erase, stp62_sicar_peq_1mf_1a_Merge], output=stp63_sicar_peq_1a2mf_2a4mf_merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,area_ha,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,sicar_pa_ind_status,0,2,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,sicar_pa_ind_tipo_i,0,3,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,mod_fiscais,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,perfil_imov,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp62_sicar_peq_1mf_1a_Merge,perfil_imovel,0,255;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp63_sicar_peq_1a2mf_2a4mf_erase,Shape_Area,-1,-1")

    # Process: Copy Features (Copy Features) (management)
    stp64_sicar_pequenos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos"
    arcpy.management.CopyFeatures(in_features=stp63_sicar_peq_1a2mf_2a4mf_merge, out_feature_class=stp64_sicar_pequenos)

    # Process: Calculate Field (Calculate Field) (management)
    stp64_sicar_pequenos_2_ = arcpy.management.CalculateField(in_table=stp64_sicar_pequenos, field="perfil_imovel", expression="\"SICAR Pequenos\"")[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sobreposicao_pequenos2()

# %%
def trat_sobrep_grandes_medios():  # 05_trat_sobreposicao_medios_grandes

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp4_sicar_medio = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_medio"
    stp4_sicar_medio_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_medio"
    stp4_sicar_grande = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp4_sicar_grande"

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp4_sicar_medio_Layer, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp4_sicar_medio, where_clause="mod_fiscais > 4 And mod_fiscais <= 10")

    # Process: Export Features (2) (Export Features) (conversion)
    stp7_sicar_med_4a10mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp7_sicar_med_4a10mf"
    arcpy.conversion.ExportFeatures(in_features=stp4_sicar_medio_Layer, out_features=stp7_sicar_med_4a10mf, field_mapping="area_ha \"area_imove\" true true false 8 Double 0 0,First,#,stp4_sicar_medio_Layer,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,stp4_sicar_medio_Layer,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,stp4_sicar_medio_Layer,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp4_sicar_medio_Layer,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,stp4_sicar_medio_Layer,perfil_imovel,0,255;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp4_sicar_medio_Layer,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp4_sicar_medio_Layer,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (2) (Remove Overlap (multiple)) (analysis)
    stp71_sicar_med_4a10mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp71_sicar_med_4a10mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp7_sicar_med_4a10mf], out_feature_class=stp71_sicar_med_4a10mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (4) (Select Layer By Attribute) (management)
    stp4_sicar_medio_Layer_2_, Count_4_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp4_sicar_medio_3_, where_clause="mod_fiscais > 10")

    # Process: Export Features (Export Features) (conversion)
    stp7_sicar_med_acima10mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp7_sicar_med_acima10mf"
    arcpy.conversion.ExportFeatures(in_features=stp4_sicar_medio_Layer_2_, out_features=stp7_sicar_med_acima10mf, field_mapping="area_ha \"area_imove\" true true false 8 Double 0 0,First,#,stp4_sicar_medio_Layer1,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,stp4_sicar_medio_Layer1,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,stp4_sicar_medio_Layer1,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp4_sicar_medio_Layer1,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,stp4_sicar_medio_Layer1,perfil_imovel,0,255;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp4_sicar_medio_Layer1,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp4_sicar_medio_Layer1,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (4) (Remove Overlap (multiple)) (analysis)
    stp71_sicar_med_acima10mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp71_sicar_med_acima10mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp7_sicar_med_acima10mf], out_feature_class=stp71_sicar_med_acima10mf_woverlap, method="THIESSEN")

    # Process: Remove Overlap (multiple) (3) (Remove Overlap (multiple)) (analysis)
    stp8_sicar_grande_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp8_sicar_grande_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp4_sicar_grande], out_feature_class=stp8_sicar_grande_woverlap, method="THIESSEN")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sobrep_grandes_medios()

# %%
def trat_sobrep_grandes_medios2():  # 5_1_trat_sobrep_medios_grandes

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp8_sicar_grande_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp8_sicar_grande_woverlap"
    stp71_sicar_med_acima10mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_acima10mf_woverlap"
    stp71_sicar_med_4a10mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap"
    stp64_sicar_pequenos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos"
    hid_massa_dagua = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua"

    # Process: Copy Features (2) (Copy Features) (management)
    stp81_sicar_grandes = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp81_sicar_grandes"
    arcpy.management.CopyFeatures(in_features=stp8_sicar_grande_woverlap_3_, out_feature_class=stp81_sicar_grandes)

    # Process: Erase (Erase) (analysis)
    stp72_sicar_med_acima10mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase"
    arcpy.analysis.Erase(in_features=stp71_sicar_med_acima10mf_woverlap_3_, erase_features=stp71_sicar_med_4a10mf_woverlap_3_, out_feature_class=stp72_sicar_med_acima10mf_erase)

    # Process: Merge (Merge) (management)
    stp72_sicar_1mf_1a2mf_erase_merge = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_1mf_1a2mf_erase_merge"
    arcpy.management.Merge(inputs=[stp72_sicar_med_acima10mf_erase, stp71_sicar_med_4a10mf_woverlap_3_], output=stp72_sicar_1mf_1a2mf_erase_merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,area_ha,0,2,C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,ind_tipo_i,0,3,C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\stp71_sicar_med_4a10mf_woverlap,perfil_imovel,0,255;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp72_sicar_med_acima10mf_erase,Shape_Area,-1,-1")

    # Process: Copy Features (Copy Features) (management)
    stp73_sicar_medios = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp73_sicar_medios"
    arcpy.management.CopyFeatures(in_features=stp72_sicar_1mf_1a2mf_erase_merge, out_feature_class=stp73_sicar_medios)

    # Process: Erase (2) (Erase) (analysis)
    stp9_sicar_med_erase_peq = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq"
    arcpy.analysis.Erase(in_features=stp73_sicar_medios, erase_features=stp64_sicar_pequenos, out_feature_class=stp9_sicar_med_erase_peq)

    # Process: Merge (2) (Merge) (management)
    stp9_sicar_med_peq = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq"
    arcpy.management.Merge(inputs=[stp9_sicar_med_erase_peq, stp64_sicar_pequenos], output=stp9_sicar_med_peq, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,ind_status,0,2,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,ind_tipo_i,0,3,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_erase_peq,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp64_sicar_pequenos,perfil_imovel,0,255")

    # Process: Erase (3) (Erase) (analysis)
    stp9_sicar_grandes_erase_peqmed = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed"
    arcpy.analysis.Erase(in_features=stp81_sicar_grandes, erase_features=stp9_sicar_med_peq, out_feature_class=stp9_sicar_grandes_erase_peqmed)

    # Process: Merge (3) (Merge) (management)
    stp9_sicar_grandes_era_Merge = "C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp9_sicar_grandes_era_Merge"
    arcpy.management.Merge(inputs=[stp9_sicar_grandes_erase_peqmed, stp9_sicar_med_peq], output=stp9_sicar_grandes_era_Merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq,area_ha,-1,-1;ind_status \"ind_status\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,ind_status,0,2,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq,ind_status,0,2;ind_tipo_i \"ind_tipo_i\" true true false 3 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,ind_tipo_i,0,3,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq,ind_tipo_i,0,3;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_med_peq,perfil_imovel,0,255;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp9_sicar_grandes_erase_peqmed,Shape_Area,-1,-1")

    # Process: Erase (4) (Erase) (analysis)
    stp91_sicar_tratado_sem_massagua = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp91_sicar_tratado_sem_massagua"
    arcpy.analysis.Erase(in_features=stp9_sicar_grandes_era_Merge, erase_features=hid_massa_dagua, out_feature_class=stp91_sicar_tratado_sem_massagua)

    # Process: Copy Features (3) (Copy Features) (management)
    sicar_tratado = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sicar_tratado"
    arcpy.management.CopyFeatures(in_features=stp91_sicar_tratado_sem_massagua, out_feature_class=sicar_tratado)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sobrep_grandes_medios2()

# %%
def trat_sigef_snci():  # 06_tratamento_sigef_snci

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    arcpy.ImportToolbox(r"c:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Data Management Tools.tbx")
    amz_municipios_ibge = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\amz_municipios_ibge"
    sigef_privado = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\sigef_privado"
    amz_municipios_ibge_2_ = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\amz_municipios_ibge"
    snci_privado = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\snci_privado"

    # Process: Calculate Geometry Attributes (2) (Calculate Geometry Attributes) (management)
    sigef_privado_3_ = arcpy.management.CalculateGeometryAttributes(in_features=sigef_privado, geometry_property=[["area_ha", "AREA"]], area_unit="HECTARES", coordinate_system="PROJCS[\"IBGE_Albers_Equal_Area_Conic_Amz\",GEOGCS[\"GCS_SIRGAS_2000\",DATUM[\"D_SIRGAS_2000\",SPHEROID[\"GRS_1980\",6378137.0,298.257222101]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]],PROJECTION[\"Albers\"],PARAMETER[\"False_Easting\",0.0],PARAMETER[\"False_Northing\",0.0],PARAMETER[\"Central_Meridian\",-59.0],PARAMETER[\"Standard_Parallel_1\",1.0],PARAMETER[\"Standard_Parallel_2\",-14.0],PARAMETER[\"Latitude_Of_Origin\",5.0],UNIT[\"Meter\",1.0]]")[0]

    # Process: Intersect (2) (Intersect) (analysis)
    stp10_sigef_privado_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun"
    arcpy.analysis.Intersect(in_features=[[amz_municipios_ibge, ""], [sigef_privado_3_, ""]], out_feature_class=stp10_sigef_privado_mun)

    # Process: Add Field (2) (Add Field) (management)
    stp10_sigef_privado_mun_5_ = arcpy.management.AddField(in_table=stp10_sigef_privado_mun, field_name="mod_fiscais", field_type="DOUBLE")[0]

    # Process: Calculate Field (Calculate Field) (management)
    stp10_sigef_privado_mun_2_ = arcpy.management.CalculateField(in_table=stp10_sigef_privado_mun_5_, field="mod_fiscais", expression="!area_ha!/!mf!")[0]

    # Process: Calculate Field (3) (Calculate Field) (management)
    stp10_sigef_privado_mun_3_ = arcpy.management.CalculateField(in_table=stp10_sigef_privado_mun_2_, field="Perfil_imovel", expression="reclass(!mod_fiscais!)", code_block="""def reclass(mod_fiscais):
    if (mod_fiscais <= 4):
        return \"SIGEF Pequeno\"
    elif (mod_fiscais > 4 and mod_fiscais <= 15):
        return \"SIGEF Medio\"
    elif (mod_fiscais > 15):
        return \"SIGEF Grande\"
""")[0]

    # Process: Calculate Geometry Attributes (Calculate Geometry Attributes) (management)
    snci_privado_2_ = arcpy.management.CalculateGeometryAttributes(in_features=snci_privado, geometry_property=[["area_ha", "AREA"]], area_unit="HECTARES", coordinate_system="PROJCS[\"IBGE_Albers_Equal_Area_Conic_Amz\",GEOGCS[\"GCS_SIRGAS_2000\",DATUM[\"D_SIRGAS_2000\",SPHEROID[\"GRS_1980\",6378137.0,298.257222101]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]],PROJECTION[\"Albers\"],PARAMETER[\"False_Easting\",0.0],PARAMETER[\"False_Northing\",0.0],PARAMETER[\"Central_Meridian\",-59.0],PARAMETER[\"Standard_Parallel_1\",1.0],PARAMETER[\"Standard_Parallel_2\",-14.0],PARAMETER[\"Latitude_Of_Origin\",5.0],UNIT[\"Meter\",1.0]]")[0]

    # Process: Intersect (3) (Intersect) (analysis)
    stp10_snci_privado_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_mun"
    arcpy.analysis.Intersect(in_features=[[amz_municipios_ibge_2_, ""], [snci_privado_2_, ""]], out_feature_class=stp10_snci_privado_mun)

    # Process: Add Field (Add Field) (management)
    stp10_snci_privado_mun_3_ = arcpy.management.AddField(in_table=stp10_snci_privado_mun, field_name="mod_fiscais", field_type="DOUBLE")[0]

    # Process: Calculate Field (2) (Calculate Field) (management)
    stp10_sigef_privado_mun_4_ = arcpy.management.CalculateField(in_table=stp10_snci_privado_mun_3_, field="mod_fiscais", expression="!area_ha!/!mf!")[0]

    # Process: Calculate Field (4) (Calculate Field) (management)
    stp10_snci_privado_mun_2_ = arcpy.management.CalculateField(in_table=stp10_sigef_privado_mun_4_, field="Perfil_imovel", expression="reclass(!mod_fiscais!)", code_block="""def reclass(mod_fiscais):
    if (mod_fiscais <= 4):
        return \"SNCI Pequeno\"
    elif (mod_fiscais > 4 and mod_fiscais <= 15):
        return \"SNCI Medio\"
    elif (mod_fiscais > 15):
        return \"SNCI Grande\"
""")[0]

    # Process: Erase (Erase) (analysis)
    stp10_snci_privado_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase"
    arcpy.analysis.Erase(in_features=stp10_snci_privado_mun_2_, erase_features=stp10_sigef_privado_mun_3_, out_feature_class=stp10_snci_privado_erase)

    # Process: Merge (Merge) (management)
    stp10_sigef_snci_privado = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"
    arcpy.management.Merge(inputs=[stp10_sigef_privado_mun_3_, stp10_snci_privado_erase], output=stp10_sigef_snci_privado, field_mappings="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_privado_mun,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_snci_privado_erase,Perfil_imovel,0,512")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sigef_snci()

# %%
def trat_sigef_snci_peq():  # 07_trat_sobreposicao_pequenos

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp10_sigef_snci_privado = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"
    stp10_sigef_snci_privado_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"
    stp10_sigef_snci_privado_4_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado, where_clause="mod_fiscais <= 1 And Perfil_imovel IN ('SIGEF Pequeno', 'SNCI Pequeno')")

    # Process: Export Features (Export Features) (conversion)
    stp11_sigef_snci_peq_1mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay, out_features=stp11_sigef_snci_peq_1mf, use_field_alias_as_name="NOT_USE_ALIAS", field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (2) (Remove Overlap (multiple)) (analysis)
    stp11_sigef_snci_peq_1mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp11_sigef_snci_peq_1mf], out_feature_class=stp11_sigef_snci_peq_1mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (4) (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay1, Count_4_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado_3_, where_clause="mod_fiscais > 1 And mod_fiscais <= 2 And Perfil_imovel IN ('SIGEF Pequeno', 'SNCI Pequeno')")

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay2, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado_4_, where_clause="mod_fiscais > 2 And Perfil_imovel IN ('SIGEF Pequeno', 'SNCI Pequeno')")

    # Process: Export Features (2) (Export Features) (conversion)
    stp11_sigef_snci_peq_2a4mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_2a4mf"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay2, out_features=stp11_sigef_snci_peq_2a4mf, field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay2,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay2,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay2,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay2,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay2,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay2,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay2,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (3) (Remove Overlap (multiple)) (analysis)
    stp11_sigef_snci_peq_2a4mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_2a4mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp11_sigef_snci_peq_2a4mf], out_feature_class=stp11_sigef_snci_peq_2a4mf_woverlap, method="THIESSEN")

    # Process: Export Features (4) (Export Features) (conversion)
    stp11_sigef_snci_peq_1a2mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay1, out_features=stp11_sigef_snci_peq_1a2mf, field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay1,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay1,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay1,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay1,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay1,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay1,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay1,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (4) (Remove Overlap (multiple)) (analysis)
    stp11_sigef_snci_peq_1a2mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1a2mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp11_sigef_snci_peq_1a2mf], out_feature_class=stp11_sigef_snci_peq_1a2mf_woverlap, method="THIESSEN")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sigef_snci_peq()

# %%
def trat_sigef_snci_peq2():  # 7_1_trat_sobrep_pequenos

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp11_sigef_snci_peq_2a4mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_2a4mf_woverlap"
    stp11_sigef_snci_peq_1a2mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1a2mf_woverlap"
    stp11_sigef_snci_peq_1mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap"

    # Process: Erase (Erase) (analysis)
    stp11_sigef_snci_peq_1mf_1a2mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase"
    arcpy.analysis.Erase(in_features=stp11_sigef_snci_peq_1a2mf_woverlap_3_, erase_features=stp11_sigef_snci_peq_1mf_woverlap_3_, out_feature_class=stp11_sigef_snci_peq_1mf_1a2mf_erase)

    # Process: Merge (Merge) (management)
    stp11_sigef_snci_peq_1a2mf_merge = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge"
    arcpy.management.Merge(inputs=[stp11_sigef_snci_peq_1mf_1a2mf_erase, stp11_sigef_snci_peq_1mf_woverlap_3_], output=stp11_sigef_snci_peq_1a2mf_merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,ORIG_FID,-1,-1;CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\stp11_sigef_snci_peq_1mf_woverlap,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1mf_1a2mf_erase,Shape_area,-1,-1")

    # Process: Erase (2) (Erase) (analysis)
    stp11_sigef_snci_peq_1a2mf_2a4mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase"
    arcpy.analysis.Erase(in_features=stp11_sigef_snci_peq_2a4mf_woverlap_3_, erase_features=stp11_sigef_snci_peq_1a2mf_merge, out_feature_class=stp11_sigef_snci_peq_1a2mf_2a4mf_erase)

    # Process: Merge (2) (Merge) (management)
    spt11_sigef_snci_1a4mf_merge = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\spt11_sigef_snci_1a4mf_merge"
    arcpy.management.Merge(inputs=[stp11_sigef_snci_peq_1a2mf_2a4mf_erase, stp11_sigef_snci_peq_1a2mf_merge], output=spt11_sigef_snci_1a4mf_merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,ORIG_FID,-1,-1;CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_merge,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_peq_1a2mf_2a4mf_erase,Shape_area,-1,-1")

    # Process: Copy Features (Copy Features) (management)
    stp11_sigef_snci_pequenos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos"
    arcpy.management.CopyFeatures(in_features=spt11_sigef_snci_1a4mf_merge, out_feature_class=stp11_sigef_snci_pequenos)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sigef_snci_peq2()

# %%
def trat_sigef_snci_granmed():  # 08_trat_sobreposicao_medios_grandes

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp10_sigef_snci_privado_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"
    stp10_sigef_snci_privado_2_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"
    stp10_sigef_snci_privado = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp10_sigef_snci_privado"

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay4, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado_3_, where_clause="mod_fiscais > 4 And mod_fiscais <= 10 And Perfil_imovel IN ('SIGEF Medio', 'SNCI Medio')")

    # Process: Export Features (Export Features) (conversion)
    stp12_sigef_snci_med_4a10mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_4a10mf"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay4, out_features=stp12_sigef_snci_med_4a10mf, field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay4,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay4,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay4,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay4,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay4,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay4,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay4,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (2) (Remove Overlap (multiple)) (analysis)
    stp12_sicar_med_4a10mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sicar_med_4a10mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp12_sigef_snci_med_4a10mf], out_feature_class=stp12_sicar_med_4a10mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (4) (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay5, Count_4_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado_2_, where_clause="mod_fiscais > 10 And Perfil_imovel IN ('SIGEF Medio', 'SNCI Medio')")

    # Process: Export Features (3) (Export Features) (conversion)
    stp12_sigef_snci_med_acima10mf = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay5, out_features=stp12_sigef_snci_med_acima10mf, field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay5,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay5,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay5,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay5,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay5,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay5,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay5,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (4) (Remove Overlap (multiple)) (analysis)
    stp12_sicar_med_acima10mf_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sicar_med_acima10mf_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp12_sigef_snci_med_acima10mf], out_feature_class=stp12_sicar_med_acima10mf_woverlap, method="THIESSEN")

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    stp10_sigef_snci_privado_Lay3, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp10_sigef_snci_privado, where_clause="Perfil_imovel IN ('SIGEF Grande', 'SNCI Grande')")

    # Process: Export Features (2) (Export Features) (conversion)
    stp12_sigef_snci_grandes = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_grandes"
    with arcpy.EnvManager(outputZFlag="Disabled"):
        arcpy.conversion.ExportFeatures(in_features=stp10_sigef_snci_privado_Lay3, out_features=stp12_sigef_snci_grandes, field_mapping="CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,stp10_sigef_snci_privado_Lay3,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,stp10_sigef_snci_privado_Lay3,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay3,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay3,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,stp10_sigef_snci_privado_Lay3,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay3,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,stp10_sigef_snci_privado_Lay3,Shape_Area,-1,-1")

    # Process: Remove Overlap (multiple) (3) (Remove Overlap (multiple)) (analysis)
    stp12_sigef_snci_grande_woverlap = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_grande_woverlap"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp12_sigef_snci_grandes], out_feature_class=stp12_sigef_snci_grande_woverlap, method="THIESSEN")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sigef_snci_granmed()

# %%
def trat_sigef_snci_granmed2():  # 8_1_trat_sobrep_medios_grandes

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp12_sigef_snci_grande_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp12_sigef_snci_grande_woverlap"
    stp12_sicar_med_acima10mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_acima10mf_woverlap"
    stp12_sicar_med_4a10mf_woverlap_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap"
    stp11_sigef_snci_pequenos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos"
    hid_massa_dagua = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua"

    # Process: Copy Features (2) (Copy Features) (management)
    stp14_sicar_grandes = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp14_sicar_grandes"
    arcpy.management.CopyFeatures(in_features=stp12_sigef_snci_grande_woverlap_3_, out_feature_class=stp14_sicar_grandes)

    # Process: Erase (Erase) (analysis)
    stp12_sigef_snci_med_acima10mf_erase = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase"
    arcpy.analysis.Erase(in_features=stp12_sicar_med_acima10mf_woverlap_3_, erase_features=stp12_sicar_med_4a10mf_woverlap_3_, out_feature_class=stp12_sigef_snci_med_acima10mf_erase)

    # Process: Merge (Merge) (management)
    stp12_sigef_snci_4a15mf_medios_merge = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_4a15mf_medios_merge"
    arcpy.management.Merge(inputs=[stp12_sigef_snci_med_acima10mf_erase, stp12_sicar_med_4a10mf_woverlap_3_], output=stp12_sigef_snci_4a15mf_medios_merge, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,ORIG_FID,-1,-1;CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\stp12_sicar_med_4a10mf_woverlap,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_med_acima10mf_erase,Shape_area,-1,-1")

    # Process: Copy Features (Copy Features) (management)
    stp12_sigef_snci_medios = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp12_sigef_snci_medios"
    arcpy.management.CopyFeatures(in_features=stp12_sigef_snci_4a15mf_medios_merge, out_feature_class=stp12_sigef_snci_medios)

    # Process: Erase (2) (Erase) (analysis)
    stp13_sigef_snci_med_erase_peq = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq"
    arcpy.analysis.Erase(in_features=stp12_sigef_snci_medios, erase_features=stp11_sigef_snci_pequenos, out_feature_class=stp13_sigef_snci_med_erase_peq)

    # Process: Merge (2) (Merge) (management)
    stp13_sigef_snci_peq_med = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med"
    arcpy.management.Merge(inputs=[stp13_sigef_snci_med_erase_peq, stp11_sigef_snci_pequenos], output=stp13_sigef_snci_peq_med, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,ORIG_FID,-1,-1;CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_med_erase_peq,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp11_sigef_snci_pequenos,Perfil_imovel,0,512")

    # Process: Erase (3) (Erase) (analysis)
    stp15_sigef_snci_grandes_erase_peqmed = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed"
    arcpy.analysis.Erase(in_features=stp14_sicar_grandes, erase_features=stp13_sigef_snci_peq_med, out_feature_class=stp15_sigef_snci_grandes_erase_peqmed)

    # Process: Merge (3) (Merge) (management)
    stp15_sigef_snci_peq_med_gra = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_peq_med_gra"
    arcpy.management.Merge(inputs=[stp15_sigef_snci_grandes_erase_peqmed, stp13_sigef_snci_peq_med], output=stp15_sigef_snci_peq_med_gra, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,ORIG_FID,-1,-1;CD_MUN \"CD_MUN\" true true false 7 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,CD_MUN,0,7,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,CD_MUN,0,7;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,NM_MUN,0,60;area_ha \"area_ha\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,mod_fiscais,-1,-1;Perfil_imovel \"Perfil_imovel\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,Perfil_imovel,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp13_sigef_snci_peq_med,Perfil_imovel,0,512;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp15_sigef_snci_grandes_erase_peqmed,Shape_area,-1,-1")

    # Process: Erase (4) (Erase) (analysis)
    stp16_sigef_snci_tratado_sem_massagua = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp16_sigef_snci_tratado_sem_massagua"
    arcpy.analysis.Erase(in_features=stp15_sigef_snci_peq_med_gra, erase_features=hid_massa_dagua, out_feature_class=stp16_sigef_snci_tratado_sem_massagua)

    # Process: Copy Features (3) (Copy Features) (management)
    sigef_snci_tratado = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado"
    arcpy.management.CopyFeatures(in_features=stp16_sigef_snci_tratado_sem_massagua, out_feature_class=sigef_snci_tratado)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        trat_sigef_snci_granmed2()

# %%
def areas_protegidas():  # 09_areas_protegidas

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    sicar_tratado = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sicar_tratado"
    sigef_snci_tratado = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado"
    tindigena_funai = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\tindigena_funai"
    tquilombolas_iterpa = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\tquilombolas_iterpa"
    tquilombolas_incra = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\tquilombolas_incra"
    stp3_apas_mma = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma"
    stp3_uc_sem_apa_mma = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma"
    fpnd_2020 = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\fpnd_2020"
    stp3_apas_mma_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma"
    assentamento_incra = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra"
    assentamentos_iterpa = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamentos_iterpa"

    # Process: Erase (Erase) (analysis)
    stp101_sicar_erase_sigef_snci = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp101_sicar_erase_sigef_snci"
    arcpy.analysis.Erase(in_features=sicar_tratado, erase_features=sigef_snci_tratado, out_feature_class=stp101_sicar_erase_sigef_snci)

    # Process: Merge (Merge) (management)
    areas_privadas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas"
    arcpy.management.Merge(inputs=[stp101_sicar_erase_sigef_snci, sigef_snci_tratado], output=areas_privadas, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp101_sicar_erase_sigef_snci,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp101_sicar_erase_sigef_snci,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp101_sicar_erase_sigef_snci,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp101_sicar_erase_sigef_snci,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\sigef_snci_tratado,Perfil_imovel,0,512")

    # Process: Dissolve (Dissolve) (management)
    stp102_ti_dissolve = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp102_ti_dissolve"
    arcpy.management.Dissolve(in_features=tindigena_funai, out_feature_class=stp102_ti_dissolve, dissolve_field=["terrai_cod", "terrai_nom", "fase_ti"])

    # Process: Copy Features (9) (Copy Features) (management)
    terras_indigenas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas"
    arcpy.management.CopyFeatures(in_features=stp102_ti_dissolve, out_feature_class=terras_indigenas)

    # Process: Intersect (Intersect) (analysis)
    stp102_ti_dissolve_intersect = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp102_ti_dissolve_intersect"
    arcpy.analysis.Intersect(in_features=[[terras_indigenas, ""]], out_feature_class=stp102_ti_dissolve_intersect)

    # Process: Dissolve (3) (Dissolve) (management)
    stp103_quilombolas_iterpa_diss = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_iterpa_diss"
    arcpy.management.Dissolve(in_features=tquilombolas_iterpa, out_feature_class=stp103_quilombolas_iterpa_diss, dissolve_field=["ID", "COMUNIDADE"])

    # Process: Dissolve (2) (Dissolve) (management)
    stp103_quilombolas_incra_diss = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_diss"
    arcpy.management.Dissolve(in_features=tquilombolas_incra, out_feature_class=stp103_quilombolas_incra_diss, dissolve_field=["cd_quilomb", "nm_comunid", "fase", "esfera"])

    # Process: Erase (2) (Erase) (analysis)
    stp103_quilombolas_incra_erase_iterpa = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_erase_iterpa"
    arcpy.analysis.Erase(in_features=stp103_quilombolas_incra_diss, erase_features=stp103_quilombolas_iterpa_diss, out_feature_class=stp103_quilombolas_incra_erase_iterpa)

    # Process: Merge (2) (Merge) (management)
    quilombolas_iterpa_incra = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra"
    arcpy.management.Merge(inputs=[stp103_quilombolas_iterpa_diss, stp103_quilombolas_incra_erase_iterpa], output=quilombolas_iterpa_incra, field_mappings="cd_quilomb \"cd_quilomb\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_erase_iterpa,cd_quilomb,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_iterpa_diss,ID,-1,-1;nm_comunid \"nm_comunid\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_erase_iterpa,nm_comunid,0,50,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_iterpa_diss,COMUNIDADE,0,254;esfera \"esfera\" true true false 9 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_erase_iterpa,esfera,0,9;fase \"fase\" true true false 20 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp103_quilombolas_incra_erase_iterpa,fase,0,20")

    # Process: Merge (3) (Merge) (management)
    stp104_ucs_completas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_ucs_completas"
    arcpy.management.Merge(inputs=[stp3_apas_mma, stp3_uc_sem_apa_mma], output=stp104_ucs_completas, field_mappings="fid_1 \"fid_1\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,fid_1,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,fid_1,-1,-1;id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,nome_uc,0,254;wdpa_pid \"wdpa_pid\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,wdpa_pid,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,wdpa_pid,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,esfera,0,254;ano_criaca \"ano_criaca\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,ano_criaca,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,ano_criaca,0,254;qualidade \"qualidade\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,qualidade,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,qualidade,0,254;ato_criaca \"ato_criaca\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,ato_criaca,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,ato_criaca,0,254;codigo_uc \"codigo_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,codigo_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,codigo_uc,0,254;nome_og \"nome_og\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,nome_og,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,nome_og,0,254;hectares \"hectares\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,hectares,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,hectares,-1,-1;nome_abrev \"nome_abrev\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,nome_abrev,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,nome_abrev,0,254;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_uc_sem_apa_mma,Shape_Area,-1,-1")

    # Process: Dissolve (4) (Dissolve) (management)
    stp104_ucs_dissolve = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_ucs_dissolve"
    arcpy.management.Dissolve(in_features=stp104_ucs_completas, out_feature_class=stp104_ucs_dissolve, dissolve_field=["id_uc", "nome_uc", "categoria", "grupo", "esfera"])

    # Process: Repair Geometry (Repair Geometry) (management)
    Repaired_Input_Features = arcpy.management.RepairGeometry(in_features=fpnd_2020, delete_null="DELETE_NULL")[0]

    # Process: Dissolve (5) (Dissolve) (management)
    stp105_fpnd_diss = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp105_fpnd_diss"
    arcpy.management.Dissolve(in_features=Repaired_Input_Features, out_feature_class=stp105_fpnd_diss, dissolve_field=["nome", "governo"])

    # Process: Erase (8) (Erase) (analysis)
    stp105_fpnd_erase_apas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp105_fpnd_erase_apas"
    arcpy.analysis.Erase(in_features=stp105_fpnd_diss, erase_features=stp3_apas_mma_3_, out_feature_class=stp105_fpnd_erase_apas)

    # Process: Copy Features (10) (Copy Features) (management)
    areas_nao_destinadas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas"
    arcpy.management.CopyFeatures(in_features=stp105_fpnd_erase_apas, out_feature_class=areas_nao_destinadas)

    # Process: Erase (9) (Erase) (analysis)
    stp106_assent_incra_erase_iterpa = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa"
    arcpy.analysis.Erase(in_features=assentamento_incra, erase_features=assentamentos_iterpa, out_feature_class=stp106_assent_incra_erase_iterpa)

    # Process: Merge (9) (Merge) (management)
    stp106_assentamentos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assentamentos"
    arcpy.management.Merge(inputs=[assentamento_incra, stp106_assent_incra_erase_iterpa], output=stp106_assentamentos, field_mappings="ut_classe \"ut_classe\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra,ut_classe,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa,ut_classe,0,254;ut_clsimpl \"ut_clsimpl\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra,ut_clsimpl,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa,ut_clsimpl,0,254;ut_cod \"ut_cod\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra,ut_cod,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa,ut_cod,0,254;ut_esfera \"ut_esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra,ut_esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa,ut_esfera,0,254;ut_nome \"ut_nome\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\assentamento_incra,ut_nome,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assent_incra_erase_iterpa,ut_nome,0,254")

    # Process: Remove Overlap (multiple) (Remove Overlap (multiple)) (analysis)
    stp106_assentamentos_wove = "C:\\unidades_territoriais\\database_uts.gdb\\stp106_assentamentos_wove"
    arcpy.analysis.RemoveOverlapMultiple(in_features=[stp106_assentamentos], out_feature_class=stp106_assentamentos_wove, method="THIESSEN")

    # Process: Dissolve (6) (Dissolve) (management)
    stp106_assentamentos_diss = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assentamentos_diss"
    arcpy.management.Dissolve(in_features=stp106_assentamentos_wove, out_feature_class=stp106_assentamentos_diss, dissolve_field=["ut_classe", "ut_clsimpl", "ut_cod", "ut_esfera", "ut_nome"])

    # Process: Copy Features (11) (Copy Features) (management)
    assentamentos = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos"
    arcpy.management.CopyFeatures(in_features=stp106_assentamentos_diss, out_feature_class=assentamentos)

    # Process: Intersect (2) (Intersect) (analysis)
    stp106_assentamentos_intersect = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp106_assentamentos_intersect"
    arcpy.analysis.Intersect(in_features=[[assentamentos, ""]], out_feature_class=stp106_assentamentos_intersect)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
       areas_protegidas()

# %%
def areas_protegidas2():  # 9_1_areas_protegidas

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp104_ucs_dissolve_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_ucs_dissolve"

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    stp104_ucs_dissolve_Layer, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_ucs_dissolve_3_, where_clause="grupo = 'PI'")

    # Process: Copy Features (Copy Features) (management)
    stp104_uc_pi = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi"
    arcpy.management.CopyFeatures(in_features=stp104_ucs_dissolve_Layer, out_feature_class=stp104_uc_pi)

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_pi, where_clause="esfera = 'municipal'")

    # Process: Select Layer By Attribute (3) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer1, Count_3_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_pi, where_clause="esfera = 'estadual'")

    # Process: Select Layer By Attribute (4) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer2, Count_4_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_pi, where_clause="esfera = 'federal'")

    # Process: Select Layer By Attribute (5) (Select Layer By Attribute) (management)
    stp104_ucs_dissolve_Layer_3_, Count_5_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_ucs_dissolve_3_, where_clause="grupo = 'US'")

    # Process: Copy Features (5) (Copy Features) (management)
    stp104_uc_us = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us"
    arcpy.management.CopyFeatures(in_features=stp104_ucs_dissolve_Layer_3_, out_feature_class=stp104_uc_us)

    # Process: Select Layer By Attribute (6) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer_2_, Count_6_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_us, where_clause="esfera = 'municipal'")

    # Process: Select Layer By Attribute (7) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer1_2_, Count_7_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_us, where_clause="esfera = 'estadual'")

    # Process: Select Layer By Attribute (8) (Select Layer By Attribute) (management)
    stp104_uc_pi_Layer2_2_, Count_8_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=stp104_uc_us, where_clause="esfera = 'federal'")

    # Process: Copy Features (6) (Copy Features) (management)
    stp104_uc_us_estadual = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_estadual"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer1_2_, out_feature_class=stp104_uc_us_estadual)

    # Process: Copy Features (7) (Copy Features) (management)
    stp104_uc_us_municipal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_municipal"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer_2_, out_feature_class=stp104_uc_us_municipal)

    # Process: Erase (5) (Erase) (analysis)
    stp104_uc_us_estadual_erase_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_estadual_erase_mun"
    arcpy.analysis.Erase(in_features=stp104_uc_us_estadual, erase_features=stp104_uc_us_municipal, out_feature_class=stp104_uc_us_estadual_erase_mun)

    # Process: Merge (6) (Merge) (management)
    stp104_uc_us_est_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_est_mun"
    arcpy.management.Merge(inputs=[stp104_uc_us_estadual_erase_mun, stp104_uc_us_municipal], output=stp104_uc_us_est_mun, field_mappings="id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,Shape_Area,-1,-1")

    # Process: Copy Features (8) (Copy Features) (management)
    stp104_uc_us_federal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_federal"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer2_2_, out_feature_class=stp104_uc_us_federal)

    # Process: Erase (6) (Erase) (analysis)
    stp104_uc_us_fed_erase_est_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_fed_erase_est_mun"
    arcpy.analysis.Erase(in_features=stp104_uc_us_federal, erase_features=stp104_uc_us_est_mun, out_feature_class=stp104_uc_us_fed_erase_est_mun)

    # Process: Merge (7) (Merge) (management)
    stp104_uc_us_esferas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_esferas"
    arcpy.management.Merge(inputs=[stp104_uc_us_est_mun, stp104_uc_us_fed_erase_est_mun], output=stp104_uc_us_esferas, field_mappings="id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_area,-1,-1")

    # Process: Copy Features (3) (Copy Features) (management)
    stp104_uc_pi_estadual = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer1, out_feature_class=stp104_uc_pi_estadual)

    # Process: Copy Features (2) (Copy Features) (management)
    stp104_uc_pi_municipal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer, out_feature_class=stp104_uc_pi_municipal)

    # Process: Erase (3) (Erase) (analysis)
    stp104_uc_pi_estadual_erase_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun"
    arcpy.analysis.Erase(in_features=stp104_uc_pi_estadual, erase_features=stp104_uc_pi_municipal, out_feature_class=stp104_uc_pi_estadual_erase_mun)

    # Process: Merge (4) (Merge) (management)
    stp104_uc_pi_est_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun"
    arcpy.management.Merge(inputs=[stp104_uc_pi_estadual_erase_mun, stp104_uc_pi_municipal], output=stp104_uc_pi_est_mun, field_mappings="id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_estadual_erase_mun,Shape_area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_municipal,Shape_Area,-1,-1")

    # Process: Copy Features (4) (Copy Features) (management)
    stp104_uc_pi_federal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_federal"
    arcpy.management.CopyFeatures(in_features=stp104_uc_pi_Layer2, out_feature_class=stp104_uc_pi_federal)

    # Process: Erase (4) (Erase) (analysis)
    stp104_uc_pi_fed_erase_est_mun = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun"
    arcpy.analysis.Erase(in_features=stp104_uc_pi_federal, erase_features=stp104_uc_pi_est_mun, out_feature_class=stp104_uc_pi_fed_erase_est_mun)

    # Process: Merge (5) (Merge) (management)
    stp104_uc_pi_esferas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas"
    arcpy.management.Merge(inputs=[stp104_uc_pi_est_mun, stp104_uc_pi_fed_erase_est_mun], output=stp104_uc_pi_esferas, field_mappings="id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_est_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_fed_erase_est_mun,Shape_area,-1,-1")

    # Process: Erase (7) (Erase) (analysis)
    stp104_uc_us_erase_pi = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi"
    arcpy.analysis.Erase(in_features=stp104_uc_us_esferas, erase_features=stp104_uc_pi_esferas, out_feature_class=stp104_uc_us_erase_pi)

    # Process: Merge (8) (Merge) (management)
    unidades_conservação = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\unidades_conservação"
    arcpy.management.Merge(inputs=[stp104_uc_us_erase_pi, stp104_uc_pi_esferas], output=unidades_conservação, field_mappings="id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_us_erase_pi,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp104_uc_pi_esferas,Shape_Area,-1,-1")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        areas_protegidas2()

# %%
def areas_privadas():  # 10_areas_privadas

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    areas_privadas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas"
    areas_nao_destinadas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas"
    stp3_apas_mma = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp3_apas_mma"
    assentamentos = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos"

    # Process: Intersect (Intersect) (analysis)
    stp107_areas_privadas_and = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and"
    arcpy.analysis.Intersect(in_features=[[areas_privadas, ""], [areas_nao_destinadas, ""]], out_feature_class=stp107_areas_privadas_and)

    # Process: Erase (Erase) (analysis)
    stp107_ap_sem_and = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_sem_and"
    arcpy.analysis.Erase(in_features=areas_privadas, erase_features=stp107_areas_privadas_and, out_feature_class=stp107_ap_sem_and)

    # Process: Merge (Merge) (management)
    stp108_ap_and = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp108_ap_and"
    arcpy.management.Merge(inputs=[stp107_ap_sem_and, stp107_areas_privadas_and], output=stp108_ap_and, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_sem_and,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_sem_and,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_sem_and,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_sem_and,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,perfil_imovel,0,255;and_nome \"nome\" true true false 200 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,nome,0,200;esfera_and \"governo\" true true false 20 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_and,governo,0,20")

    # Process: Intersect (2) (Intersect) (analysis)
    stp107_areas_privadas_apas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas"
    arcpy.analysis.Intersect(in_features=[[stp3_apas_mma, ""], [stp108_ap_and, ""]], out_feature_class=stp107_areas_privadas_apas)

    # Process: Erase (2) (Erase) (analysis)
    stp107_ap_com_and_sem_apa = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa"
    arcpy.analysis.Erase(in_features=stp108_ap_and, erase_features=stp107_areas_privadas_apas, out_feature_class=stp107_ap_com_and_sem_apa)

    # Process: Merge (2) (Merge) (management)
    stp108_ap_and_apas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp108_ap_and_apas"
    arcpy.management.Merge(inputs=[stp107_ap_com_and_sem_apa, stp107_areas_privadas_apas], output=stp108_ap_and_apas, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,perfil_imovel,0,255;and_nome \"nome\" true true false 200 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,and_nome,0,200,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,and_nome,0,200;esfera_and \"governo\" true true false 20 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_sem_apa,esfera_and,0,20,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,esfera_and,0,20;id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,nome_uc,0,254;categoria \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,categoria,0,254;grupo \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,grupo,0,254;esfera \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,esfera,0,254;nome_abrev \"nome_abrev\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_apas,nome_abrev,0,254")

    # Process: Intersect (3) (Intersect) (analysis)
    stp107_areas_privadas_assentamentos = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos"
    arcpy.analysis.Intersect(in_features=[[assentamentos, ""], [stp108_ap_and_apas, ""]], out_feature_class=stp107_areas_privadas_assentamentos)

    # Process: Erase (3) (Erase) (analysis)
    stp107_ap_com_and_apa_sem_ast = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast"
    arcpy.analysis.Erase(in_features=stp108_ap_and_apas, erase_features=stp107_areas_privadas_assentamentos, out_feature_class=stp107_ap_com_and_apa_sem_ast)

    # Process: Merge (3) (Merge) (management)
    stp108_ap_and_apas_ast = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp108_ap_and_apas_ast"
    arcpy.management.Merge(inputs=[stp107_ap_com_and_apa_sem_ast, stp107_areas_privadas_assentamentos], output=stp108_ap_and_apas_ast, field_mappings="ORIG_FID \"ORIG_FID\" true true false 4 Long 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,ORIG_FID,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ORIG_FID,-1,-1;area_ha \"area_imove\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,area_ha,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,area_ha,-1,-1;mod_fiscais \"mod_fiscais\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,mod_fiscais,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,mod_fiscais,-1,-1;perfil_imovel \"perfil_imovel\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,perfil_imovel,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,perfil_imovel,0,255;and_nome \"nome\" true true false 200 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,and_nome,0,200,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,and_nome,0,200;esfera_and \"governo\" true true false 20 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,esfera_and,0,20,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,esfera_and,0,20;id_uc \"id_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,id_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,id_uc,0,254;nome_uc \"nome_uc\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,nome_uc,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,nome_uc,0,254;categ_uc \"categoria\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,categoria,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,categoria,0,254;grupo_uc \"grupo\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,grupo,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,grupo,0,254;esfera_uc \"esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,esfera,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,esfera,0,254;nm_abrv_uc \"nome_abrev\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_ap_com_and_apa_sem_ast,nome_abrev,0,254,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,nome_abrev,0,254;classe_ast \"ut_classe\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ut_classe,0,254;clsimp_ast \"ut_clsimpl\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ut_clsimpl,0,254;cod_ast \"ut_cod\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ut_cod,0,254;esfera_ast \"ut_esfera\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ut_esfera,0,254;nome_ast \"ut_nome\" true true false 254 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp107_areas_privadas_assentamentos,ut_nome,0,254")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        areas_privadas()

# %%
def areas_privadas2():  # 10_areas_privadas_2

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    stp108_ap_and_apas_ast = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp108_ap_and_apas_ast"

    # Process: Copy Features (Copy Features) (management)
    areas_privadas_final = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final"
    arcpy.management.CopyFeatures(in_features=stp108_ap_and_apas_ast, out_feature_class=areas_privadas_final)

    # Process: Calculate Field (4) (Calculate Field) (management)
    stp108_ap_and_apas_ast_6_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ut_clsimpl", expression="\"Imóveis Rurais\"")[0]

    # Process: Calculate Field (5) (Calculate Field) (management)
    stp108_ap_and_apas_ast_2_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ut_nome", expression="!perfil_imovel!")[0]

    # Process: Calculate Field (6) (Calculate Field) (management)
    stp108_ap_and_apas_ast_7_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ut_classe", expression="reclass(!mod_fiscais!)", code_block="""def reclass(mod_fiscais):
    if (mod_fiscais <= 4):
        return \"IR Pequeno\"
    elif (mod_fiscais > 4 and mod_fiscais <= 15):
        return \"IR Medio\"
    elif (mod_fiscais > 15):
        return \"IR Grande\"
""")[0]

    # Process: Calculate Field (8) (Calculate Field) (management)
    stp108_ap_and_apas_ast_4_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ut_esfera", expression="\"\"")[0]

    # Process: Calculate Field (9) (Calculate Field) (management)
    stp108_ap_and_apas_ast_5_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ut_cod", expression="\"\"")[0]

    # Process: Calculate Field (2) (Calculate Field) (management)
    areas_privadas_final_3_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="and_esfera", expression="!esfera_and!")[0]

    # Process: Calculate Field (3) (Calculate Field) (management)
    areas_privadas_final_2_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="and_nome", expression="!and_nome!")[0]

    # Process: Calculate Field (7) (Calculate Field) (management)
    areas_privadas_final_6_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_categ", expression="!categ_uc!")[0]

    # Process: Calculate Field (10) (Calculate Field) (management)
    areas_privadas_final_5_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_nome", expression="!nome_uc!")[0]

    # Process: Calculate Field (11) (Calculate Field) (management)
    areas_privadas_final_4_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_code", expression="!id_uc!")[0]

    # Process: Calculate Field (12) (Calculate Field) (management)
    areas_privadas_final_8_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_nmabr", expression="!nm_abrv_uc!")[0]

    # Process: Calculate Field (13) (Calculate Field) (management)
    areas_privadas_final_9_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_esfera", expression="!esfera_uc!")[0]

    # Process: Calculate Field (14) (Calculate Field) (management)
    areas_privadas_final_10_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_grupo", expression="!grupo_uc!")[0]

    # Process: Calculate Field (15) (Calculate Field) (management)
    areas_privadas_final_11_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ast_code", expression="!cod_ast!")[0]

    # Process: Calculate Field (16) (Calculate Field) (management)
    areas_privadas_final_12_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="apa_classe", expression="!classe_ast!")[0]

    # Process: Calculate Field (17) (Calculate Field) (management)
    areas_privadas_final_16_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ast_nome", expression="!nome_ast!")[0]

    # Process: Calculate Field (20) (Calculate Field) (management)
    areas_privadas_final_7_ = arcpy.management.CalculateField(in_table=areas_privadas_final, field="ast_esfera", expression="!esfera_ast!")[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        areas_privadas2()

# %%
def unidades_territoriais():  # 11_unidades_territoriais

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    areas_nao_destinadas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas"
    quilombolas_iterpa_incra = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra"
    terras_indigenas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas"
    unidades_conservação = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\unidades_conservação"

    # Process: Calculate Field (Calculate Field) (management)
    areas_nao_destinadas_2_ = arcpy.management.CalculateField(in_table=areas_nao_destinadas, field="ut_classe", expression="\"Áreas não destinadas\"")[0]

    # Process: Calculate Field (2) (Calculate Field) (management)
    lml_area_densamente_edificada_a_2_ = arcpy.management.CalculateField(in_table=areas_nao_destinadas, field="ut_nome", expression="!nome!")[0]

    # Process: Add Field (Add Field) (management)
    lml_area_densamente_edificada_a_4_ = arcpy.management.AddField(in_table=areas_nao_destinadas, field_name="ut_cod", field_type="TEXT", field_length=255)[0]

    # Process: Calculate Field (3) (Calculate Field) (management)
    areas_nao_destinadas_4_ = arcpy.management.CalculateField(in_table=areas_nao_destinadas, field="ut_clsimpl", expression="\"Áreas não destinadas\"")[0]

    # Process: Calculate Field (7) (Calculate Field) (management)
    areas_nao_destinadas_3_ = arcpy.management.CalculateField(in_table=areas_nao_destinadas, field="ut_esfera", expression="!governo!")[0]

    # Process: Calculate Field (4) (Calculate Field) (management)
    quilombolas_iterpa_incra_3_ = arcpy.management.CalculateField(in_table=quilombolas_iterpa_incra, field="ut_classe", expression="\"Territórios quilombolas\"")[0]

    # Process: Calculate Field (5) (Calculate Field) (management)
    quilombolas_iterpa_incra_2_ = arcpy.management.CalculateField(in_table=quilombolas_iterpa_incra, field="ut_nome", expression="!nm_comunid!")[0]

    # Process: Calculate Field (6) (Calculate Field) (management)
    quilombolas_iterpa_incra_5_ = arcpy.management.CalculateField(in_table=quilombolas_iterpa_incra, field="ut_clsimpl", expression="\"Territórios quilombolas\"")[0]

    # Process: Calculate Field (8) (Calculate Field) (management)
    quilombolas_iterpa_incra_4_ = arcpy.management.CalculateField(in_table=quilombolas_iterpa_incra, field="ut_esfera", expression="!esfera!")[0]

    # Process: Calculate Field (9) (Calculate Field) (management)
    quilombolas_iterpa_incra_6_ = arcpy.management.CalculateField(in_table=quilombolas_iterpa_incra, field="ut_cod", expression="!cd_quilomb!")[0]

    # Process: Calculate Field (10) (Calculate Field) (management)
    terras_indigenas_3_ = arcpy.management.CalculateField(in_table=terras_indigenas, field="ut_classe", expression="\"Terras indígenas\"")[0]

    # Process: Calculate Field (11) (Calculate Field) (management)
    terras_indigenas_2_ = arcpy.management.CalculateField(in_table=terras_indigenas, field="ut_nome", expression="!terrai_nom!")[0]

    # Process: Calculate Field (12) (Calculate Field) (management)
    terras_indigenas_6_ = arcpy.management.CalculateField(in_table=terras_indigenas, field="ut_clsimpl", expression="\"Terras indígenas\"")[0]

    # Process: Calculate Field (14) (Calculate Field) (management)
    terras_indigenas_4_ = arcpy.management.CalculateField(in_table=terras_indigenas, field="ut_cod", expression="!terrai_cod!")[0]

    # Process: Select Layer By Attribute (Select Layer By Attribute) (management)
    unidades_conservação_Layer, Count = arcpy.management.SelectLayerByAttribute(in_layer_or_view=unidades_conservação, where_clause="categoria = 'Área de Proteção Ambiental'")

    # Process: Copy Features (Copy Features) (management)
    apas = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\apas"
    arcpy.management.CopyFeatures(in_features=unidades_conservação_Layer, out_feature_class=apas)

    # Process: Calculate Field (15) (Calculate Field) (management)
    apas_3_ = arcpy.management.CalculateField(in_table=apas, field="ut_classe", expression="\"APAs\"")[0]

    # Process: Calculate Field (16) (Calculate Field) (management)
    unidades_conservação_2_ = arcpy.management.CalculateField(in_table=apas, field="ut_nome", expression="!nome_uc!")[0]

    # Process: Calculate Field (17) (Calculate Field) (management)
    apas_2_ = arcpy.management.CalculateField(in_table=apas, field="ut_clsimpl", expression="\"APAs\"")[0]

    # Process: Calculate Field (18) (Calculate Field) (management)
    quilombolas_iterpa_incra_7_ = arcpy.management.CalculateField(in_table=apas, field="ut_esfera", expression="!esfera!")[0]

    # Process: Calculate Field (19) (Calculate Field) (management)
    unidades_conservação_4_ = arcpy.management.CalculateField(in_table=apas, field="ut_cod", expression="!id_uc!")[0]

    # Process: Select Layer By Attribute (2) (Select Layer By Attribute) (management)
    unidades_conservação_Layer_3_, Count_2_ = arcpy.management.SelectLayerByAttribute(in_layer_or_view=unidades_conservação, where_clause="categoria <> 'Área de Proteção Ambiental'")

    # Process: Copy Features (2) (Copy Features) (management)
    ucs_sem_apa = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa"
    arcpy.management.CopyFeatures(in_features=unidades_conservação_Layer_3_, out_feature_class=ucs_sem_apa)

    # Process: Calculate Field (20) (Calculate Field) (management)
    ucs_sem_apa_2_ = arcpy.management.CalculateField(in_table=ucs_sem_apa, field="ut_classe", expression="\"UC \"+!grupo!")[0]

    # Process: Calculate Field (21) (Calculate Field) (management)
    unidades_conservação_3_ = arcpy.management.CalculateField(in_table=ucs_sem_apa, field="ut_nome", expression="!nome_uc!")[0]

    # Process: Calculate Field (22) (Calculate Field) (management)
    ucs_sem_apa_3_ = arcpy.management.CalculateField(in_table=ucs_sem_apa, field="ut_clsimpl", expression="\"UC \"+!grupo!")[0]

    # Process: Calculate Field (23) (Calculate Field) (management)
    quilombolas_iterpa_incra_8_ = arcpy.management.CalculateField(in_table=ucs_sem_apa, field="ut_esfera", expression="!esfera!")[0]

    # Process: Calculate Field (24) (Calculate Field) (management)
    unidades_conservação_5_ = arcpy.management.CalculateField(in_table=ucs_sem_apa, field="ut_cod", expression="!id_uc!")[0]

    # Process: Add Field (2) (Add Field) (management)
    terras_indigenas_5_ = arcpy.management.AddField(in_table=terras_indigenas, field_name="ut_esfera", field_type="TEXT", field_length=255)[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        unidades_territoriais()

# %%
def unidades_territoriais2():  # 11_unidades_teriritoriais_2

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    terras_indigenas_8_ = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas"
    quilombolas_iterpa_incra_10_ = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra"
    ucs_sem_apa = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa"
    area_militares_ibge = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge"
    areas_nao_destinadas_6_ = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas"
    lml_area_densamente_edificada_a = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\lml_area_densamente_edificada_a"
    hid_massa_dagua = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua"
    apas_5_ = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\apas"
    assentamentos = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos"
    areas_privadas_final = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final"

    # Process: Erase (Erase) (analysis)
    stp200_area_edf_erase_massadagua = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua"
    arcpy.analysis.Erase(in_features=lml_area_densamente_edificada_a, erase_features=hid_massa_dagua, out_feature_class=stp200_area_edf_erase_massadagua)

    # Process: Merge (Merge) (management)
    stp201_area_edif_massadagua = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua"
    arcpy.management.Merge(inputs=[stp200_area_edf_erase_massadagua, hid_massa_dagua], output=stp201_area_edif_massadagua, field_mappings="Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,Shape_length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,Shape_area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,Shape_Area,-1,-1;ut_nome \"ut_nome\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,ut_nome,0,255,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_nome,0,255;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_cod,0,255;ut_esfera \"ut_esfera\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,ut_esfera,0,255,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_esfera,0,255;ut_classe \"ut_classe\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,ut_classe,0,255,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_classe,0,255;ut_clsimpl \"ut_clsimpl\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp200_area_edf_erase_massadagua,ut_clsimpl,0,255,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_clsimpl,0,255")

    # Process: Erase (2) (Erase) (analysis)
    stp210_apa_erase_areaedf_md = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md"
    arcpy.analysis.Erase(in_features=apas_5_, erase_features=stp201_area_edif_massadagua, out_feature_class=stp210_apa_erase_areaedf_md)

    # Process: Merge (2) (Merge) (management)
    stp211_apa_areaedf_md = "C:\\unidades_territoriais\\database_uts.gdb\\stp211_apa_areaedf_md"
    arcpy.management.Merge(inputs=[stp201_area_edif_massadagua, stp210_apa_erase_areaedf_md], output=stp211_apa_areaedf_md, field_mappings="ut_nome \"ut_nome\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua,ut_nome,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md,ut_nome,0,512;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md,ut_cod,0,512;ut_esfera \"ut_esfera\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua,ut_esfera,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md,ut_esfera,0,512;ut_classe \"ut_classe\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua,ut_classe,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md,ut_classe,0,512;ut_clsimpl \"ut_clsimpl\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp201_area_edif_massadagua,ut_clsimpl,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp210_apa_erase_areaedf_md,ut_clsimpl,0,512")

    # Process: Erase (3) (Erase) (analysis)
    stp220_apa_erase_and = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and"
    arcpy.analysis.Erase(in_features=stp211_apa_areaedf_md, erase_features=areas_nao_destinadas_6_, out_feature_class=stp220_apa_erase_and)

    # Process: Merge (3) (Merge) (management)
    stp221_and_apa_areaed_massad = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp221_and_apa_areaed_massad"
    arcpy.management.Merge(inputs=[areas_nao_destinadas_6_, stp220_apa_erase_and], output=stp221_and_apa_areaed_massad, field_mappings="ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and,ut_classe,0,255;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and,ut_nome,0,255;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and,ut_cod,0,255;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and,ut_clsimpl,0,255;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_nao_destinadas,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp220_apa_erase_and,ut_esfera,0,255")

    # Process: Erase (4) (Erase) (analysis)
    stp230_and_erase_assent = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent"
    arcpy.analysis.Erase(in_features=stp221_and_apa_areaed_massad, erase_features=assentamentos, out_feature_class=stp230_and_erase_assent)

    # Process: Merge (4) (Merge) (management)
    stp231_assent_and_apa = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp231_assent_and_apa"
    arcpy.management.Merge(inputs=[stp230_and_erase_assent, assentamentos], output=stp231_assent_and_apa, field_mappings="ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,ut_classe,0,254;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,ut_nome,0,254;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,ut_cod,0,254;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,ut_clsimpl,0,254;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,ut_esfera,0,254;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,Shape_length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp230_and_erase_assent,Shape_area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\assentamentos,Shape_Area,-1,-1")

    # Process: Erase (5) (Erase) (analysis)
    stp240_assent_erase_areasprivadas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas"
    arcpy.analysis.Erase(in_features=stp231_assent_and_apa, erase_features=areas_privadas_final, out_feature_class=stp240_assent_erase_areasprivadas)

    # Process: Merge (5) (Merge) (management)
    stp241_areasprivadas_assent_and = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp241_areasprivadas_assent_and"
    arcpy.management.Merge(inputs=[stp240_assent_erase_areasprivadas, areas_privadas_final], output=stp241_areasprivadas_assent_and, field_mappings="ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ut_classe,0,512;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ut_nome,0,512;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ut_cod,0,512;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ut_clsimpl,0,512;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ut_esfera,0,512;Shape_Length \"Shape_Length\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,Shape_length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" true true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp240_assent_erase_areasprivadas,Shape_area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,Shape_Area,-1,-1;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\areas_privadas_final,ast_esfera,0,512")

    # Process: Erase (6) (Erase) (analysis)
    stp250_areasprivadas_erase_areasmilitares = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares"
    arcpy.analysis.Erase(in_features=stp241_areasprivadas_assent_and, erase_features=area_militares_ibge, out_feature_class=stp250_areasprivadas_erase_areasmilitares)

    # Process: Merge (6) (Merge) (management)
    stp251_areasmilitares_areaspri = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp251_areasmilitares_areaspri"
    arcpy.management.Merge(inputs=[area_militares_ibge, stp250_areasprivadas_erase_areasmilitares], output=stp251_areasmilitares_areaspri, field_mappings="Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,Shape_length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,Shape_area,-1,-1;ut_nome \"ut_nome\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,ut_nome,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ut_nome,0,512;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,ut_cod,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ut_cod,0,255;ut_esfera \"ut_esfera\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,ut_esfera,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ut_esfera,0,512;ut_classe \"ut_classe\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,ut_classe,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ut_classe,0,512;ut_clsimpl \"ut_clsimpl\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\area_militares_ibge,ut_clsimpl,0,255,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ut_clsimpl,0,512;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp250_areasprivadas_erase_areasmilitares,ast_esfera,0,512")

    # Process: Erase (7) (Erase) (analysis)
    stp260_areasmilit_erase_ucs = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs"
    arcpy.analysis.Erase(in_features=stp251_areasmilitares_areaspri, erase_features=ucs_sem_apa, out_feature_class=stp260_areasmilit_erase_ucs)

    # Process: Merge (7) (Merge) (management)
    stp261_ucs_areasmilit_areasp = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp261_ucs_areasmilit_areasp"
    arcpy.management.Merge(inputs=[ucs_sem_apa, stp260_areasmilit_erase_ucs], output=stp261_ucs_areasmilit_areasp, field_mappings="Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,Shape_Area,-1,-1;ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ut_classe,0,255;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ut_nome,0,255;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ut_clsimpl,0,255;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ut_esfera,0,255;ut_cod \"ut_cod\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\ucs_sem_apa,ut_cod,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ut_cod,0,255;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp260_areasmilit_erase_ucs,ast_esfera,0,512")

    # Process: Erase (8) (Erase) (analysis)
    stp270_ucs_erase_quilombolas = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas"
    arcpy.analysis.Erase(in_features=stp261_ucs_areasmilit_areasp, erase_features=quilombolas_iterpa_incra_10_, out_feature_class=stp270_ucs_erase_quilombolas)

    # Process: Merge (8) (Merge) (management)
    stp271_quilombolas_ucs = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp271_quilombolas_ucs"
    arcpy.management.Merge(inputs=[quilombolas_iterpa_incra_10_, stp270_ucs_erase_quilombolas], output=stp271_quilombolas_ucs, field_mappings="Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,Shape_Area,-1,-1;ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ut_classe,0,512;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ut_nome,0,512;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ut_clsimpl,0,512;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ut_esfera,0,512;ut_cod \"ut_cod\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\quilombolas_iterpa_incra,ut_cod,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ut_cod,0,512;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp270_ucs_erase_quilombolas,ast_esfera,0,512")

    # Process: Erase (9) (Erase) (analysis)
    stp280_quilombolas_erase_ti = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti"
    arcpy.analysis.Erase(in_features=stp271_quilombolas_ucs, erase_features=terras_indigenas_8_, out_feature_class=stp280_quilombolas_erase_ti)

    # Process: Merge (9) (Merge) (management)
    stp281_terrasindig_quilombolas_etc = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp281_terrasindig_quilombolas_etc"
    arcpy.management.Merge(inputs=[terras_indigenas_8_, stp280_quilombolas_erase_ti], output=stp281_terrasindig_quilombolas_etc, field_mappings="Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,Shape_Area,-1,-1;ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ut_classe,0,512;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ut_nome,0,512;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ut_clsimpl,0,512;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,ut_esfera,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ut_esfera,0,512;ut_cod \"ut_cod\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\outputs\\terras_indigenas,ut_cod,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ut_cod,0,512;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp280_quilombolas_erase_ti,ast_esfera,0,512")

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        unidades_territoriais2()

# %%
def unidades_territoriais3():  # 11_unidades_teriritoriais_3

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    amz_municipios_ibge = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\amz_municipios_ibge"
    stp281_terrasindig_quilombolas_etc_3_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp281_terrasindig_quilombolas_etc"

    # Process: Intersect (Intersect) (analysis)
    stp300_ut_amaz_legal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal"
    arcpy.analysis.Intersect(in_features=[[stp281_terrasindig_quilombolas_etc_3_, ""], [amz_municipios_ibge, ""]], out_feature_class=stp300_ut_amaz_legal)

    # Process: Erase (10) (Erase) (analysis)
    stp301_area_cadastravel = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel"
    arcpy.analysis.Erase(in_features=amz_municipios_ibge, erase_features=stp300_ut_amaz_legal, out_feature_class=stp301_area_cadastravel)

    # Process: Calculate Field (13) (Calculate Field) (management)
    stp301_area_cadastravel_3_ = arcpy.management.CalculateField(in_table=stp301_area_cadastravel, field="ut_classe", expression="\"Área cadastrável\"")[0]

    # Process: Calculate Field (25) (Calculate Field) (management)
    stp301_area_cadastravel_2_ = arcpy.management.CalculateField(in_table=stp301_area_cadastravel, field="ut_nome", expression="\"Área cadastrável\"")[0]

    # Process: Calculate Field (26) (Calculate Field) (management)
    stp301_area_cadastravel_4_ = arcpy.management.CalculateField(in_table=stp301_area_cadastravel, field="ut_clsimpl", expression="\"Área cadastrável\"")[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        unidades_territoriais3()

# %%
def unidades_territoriais4():  # 11_unidades_teriritoriais_4

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    hid_massa_dagua = "C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua"
    stp301_area_cadastravel_6_ = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel"
    stp300_ut_amaz_legal = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal"
    brazilian_legal_amazon_shp = "C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\01_jobs\\02_tnc\\02_work\\tnc_demandas\\00_database\\amazonia\\brazilian_legal_amazon.shp"

    # Process: Merge (10) (Merge) (management)
    stp302_unidades_territoriais = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp302_unidades_territoriais"
    arcpy.management.Merge(inputs=[stp301_area_cadastravel_6_, stp300_ut_amaz_legal], output=stp302_unidades_territoriais, field_mappings="NM_REGIAO \"NM_REGIAO\" true true false 20 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,NM_REGIAO,0,20,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,NM_REGIAO,0,20;CD_UF \"CD_UF\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,CD_UF,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,CD_UF,-1,-1;NM_UF \"NM_UF\" true true false 50 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,NM_UF,0,50,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,NM_UF,0,50;SIGLA \"SIGLA\" true true false 2 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,SIGLA,0,2,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,SIGLA,0,2;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,NM_MUN,0,60,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,NM_MUN,0,60;geocode \"geocode\" true true false 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,geocode,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,geocode,-1,-1;mf \"mf\" true true false 4 Float 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,mf,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,mf,-1,-1;Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,Shape_Length,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,Shape_Length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,Shape_Area,-1,-1,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,Shape_Area,-1,-1;ut_classe \"ut_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,ut_classe,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ut_classe,0,512;ut_nome \"ut_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,ut_nome,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ut_nome,0,512;ut_clsimpl \"ut_clsimpl\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp301_area_cadastravel,ut_clsimpl,0,512,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ut_clsimpl,0,512;ut_esfera \"ut_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ut_esfera,0,512;ut_cod \"ut_cod\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ut_cod,0,512;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp300_ut_amaz_legal,ast_esfera,0,512")

    # Process: Erase (Erase) (analysis)
    stp303_ut_menos_massadagua = "C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua"
    arcpy.analysis.Erase(in_features=stp302_unidades_territoriais, erase_features=hid_massa_dagua, out_feature_class=stp303_ut_menos_massadagua)

    # Process: Merge (Merge) (management)
    unidades_territoriais = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\unidades_territoriais"
    arcpy.management.Merge(inputs=[hid_massa_dagua, stp303_ut_menos_massadagua], output=unidades_territoriais, field_mappings="Shape_Length \"Shape_Length\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,Shape_Length,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,Shape_Length,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,Shape_length,-1,-1;Shape_Area \"Shape_Area\" false true true 8 Double 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,Shape_Area,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,Shape_Area,-1,-1,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,Shape_area,-1,-1;ut_nome \"ut_nome\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_nome,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ut_nome,0,512;ut_cod \"ut_cod\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_cod,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ut_cod,0,512;ut_classe \"ut_classe\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_classe,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ut_classe,0,512;ut_esfera \"ut_esfera\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_esfera,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ut_esfera,0,512;ut_clsimpl \"ut_clsimpl\" true true false 255 Text 0 0,First,#,C:\\unidades_territoriais\\database_uts.gdb\\inputs\\hid_massa_dagua,ut_clsimpl,0,255,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ut_clsimpl,0,512;NM_REGIAO \"NM_REGIAO\" true true false 20 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,NM_REGIAO,0,20;CD_UF \"CD_UF\" true true false 8 Double 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,CD_UF,-1,-1;NM_UF \"NM_UF\" true true false 50 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,NM_UF,0,50;SIGLA \"SIGLA\" true true false 2 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,SIGLA,0,2;NM_MUN \"NM_MUN\" true true false 60 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,NM_MUN,0,60;geocode \"geocode\" true true false 8 Double 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,geocode,-1,-1;mf \"mf\" true true false 4 Float 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,mf,-1,-1;and_esfera \"and_esfera\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,and_esfera,0,512;apa_categ \"apa_categ\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_categ,0,512;apa_nome \"apa_nome\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_nome,0,512;apa_code \"apa_code\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_code,0,512;apa_nmabr \"apa_nmabr\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_nmabr,0,512;apa_esfera \"apa_esfera\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_esfera,0,512;apa_grupo \"apa_grupo\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_grupo,0,512;ast_code \"ast_code\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ast_code,0,512;apa_classe \"apa_classe\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,apa_classe,0,512;ast_nome \"ast_nome\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ast_nome,0,512;ast_esfera \"ast_esfera\" true true false 512 Text 0 0,First,#,C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb\\stp303_ut_menos_massadagua,ast_esfera,0,512")

    # Process: Clip (Clip) (analysis)
    unidades_territoriais_final = "C:\\unidades_territoriais\\database_uts.gdb\\outputs\\unidades_territoriais_final"
    arcpy.analysis.Clip(in_features=unidades_territoriais, clip_features=brazilian_legal_amazon_shp, out_feature_class=unidades_territoriais_final)

    # Process: Intersect (2) (Intersect) (analysis)
    stp303_sobrep_uts = "C:\\unidades_territoriais\\database_uts.gdb\\intermediate_outputs\\stp303_sobrep_uts"
    arcpy.analysis.Intersect(in_features=[[unidades_territoriais_final, ""]], out_feature_class=stp303_sobrep_uts)

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb", workspace="C:\\Users\\thaciane.silva\\OneDrive\\Documentos\\02_cursos\\mbadsa\\tcc\\dados_espaciais\\projeto\\dados_tcc_unidades_territoriais\\dados_tcc_unidades_territoriais.gdb"):
        unidades_territoriais4()
